# %%
import os

os.chdir("../..")
os.environ["CUDA_VISIBLE_DEVICES"] = "7"

# %%
import numpy as np
import matplotlib.pyplot as plt
import tqdm.notebook as tqdm

from modular_splicing.topline_results.renderer import plot_topline_results
from modular_splicing.topline_results.gather_results import results_for_main_figure

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
plt.figure(dpi=200, figsize=(5, 2.5))
res = results_for_main_figure()
plot_topline_results(res, plt.gca())
plt.legend(loc="upper left")

# %%
plt.figure(dpi=200, figsize=(4, 2.5))
res = results_for_main_figure()
plot_topline_results(res, plt.gca())
plt.legend(loc="upper left")

# %%
{k : len(v) for k, v in res.items()}
# Out:
# {'MaxEnt': 1, 'LSSI': 5, 'SpliceAI-10k': 5, 'FM': 5, 'AM': 5}

# %%
{k : np.mean(v) for k, v in res.items()}
# Out:
# {'MaxEnt': 0.21576714963174967,
#  'LSSI': 0.2499332213154964,
#  'SpliceAI-10k': 0.933344179788884,
#  'FM': 0.6715982174286156,
#  'AM': 0.7914154790654205}
