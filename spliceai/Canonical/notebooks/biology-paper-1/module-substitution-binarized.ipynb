# %%
import os

os.chdir("../..")
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
from modular_splicing.module_substitution.evaluate_combinations import table_of_combinations
from modular_splicing.module_substitution.experiment import module_substitution_main, binarization_gap_statistics

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
table_of_combinations().to_csv("output-csvs/binarized-adjusted-motif-models.csv")
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]

# %%
module_substitution_main()
# Out:
# (D=FM      67.567523
#  D=self    67.567523
#  dtype: float64,
#  D=FM      71.160124
#  D=self    77.389211
#  dtype: float64)

# %%
binarization_gap_statistics()
# Out:
# Min delta: 1.22%, max delta: 2.89%
