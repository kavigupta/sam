# %%
import os

os.chdir("../..")
os.environ["CUDA_VISIBLE_DEVICES"] = "5"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt

from modular_splicing.models_for_testing.main_models import AM, FM_full
from modular_splicing.other_experiments.rna_maps import experiment

# %%
from modular_splicing.other_experiments.rna_maps import *
from modular_splicing.other_experiments.van_nostrand_data import *

# %%
experiment(AM)
# Out:
# ...
# /scratch/kavig/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# HNRNPC      0.001110
# HNRNPCL1    0.016060
# HNRNPE1     0.005142
# HNRNPL      0.019771
# HNRNPP2     0.016606
# SRSF10     -0.013892
# dtype: float64

# %%
experiment(AM, mode="van_nostrand_overlaps")
# Out:
# ...
# /mnt/md0/ExpeditionsCommon/spliceai/Canonical/modular_splicing/other_experiments/van_nostrand_data.py:74: RuntimeWarning: Mean of empty slice
#   np.nanmean(
# /mnt/md0/ExpeditionsCommon/spliceai/Canonical/modular_splicing/other_experiments/van_nostrand_data.py:81: RuntimeWarning: Mean of empty slice
#   return np.nanmean(np.array(mean_by_cell_line), 0)

# %%
experiment(AM, mode="van_nostrand_all")

# %%
experiment(FM_full)
# Out:
# ...
# HNRNPCL1    0.019827
# HNRNPE1     0.006718
# HNRNPK      0.034557
# HNRNPL      0.006448
# HNRNPP2     0.015363
# dtype: float64
