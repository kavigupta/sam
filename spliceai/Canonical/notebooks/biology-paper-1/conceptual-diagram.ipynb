# %%
import os

os.chdir("../..")
os.environ["CUDA_VISIBLE_DEVICES"] = "7"

# %%
import numpy as np
import matplotlib.pyplot as plt
import tqdm.notebook as tqdm

from modular_splicing.topline_results.renderer import plot_topline_results
from modular_splicing.topline_results.gather_results import results_for_main_figure

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
res = {k : 100 * np.mean(v) for k, v in results_for_main_figure().items()}

# %%
plt.figure(dpi=200)
plt.scatter(0, res["SpliceAI 10k [*]"], label="SpliceAI", color="black", s=100)
plt.scatter(1, res["FM"], label="FM", color="blue", s=100)
plt.scatter(1, res["AM"], label="AM", color="red", s=100)
plt.legend()
plt.xticks([0, 1], ["Low", "Higher"])
plt.xlim(-1, 2)
plt.ylim(60, 100)
plt.xlabel("Interpretability")
plt.ylabel("Accuracy [%]")
# Out:
# Text(0, 0.5, 'Accuracy [%]')
