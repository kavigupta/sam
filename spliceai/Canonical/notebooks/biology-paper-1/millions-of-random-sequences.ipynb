# %%
import os

os.chdir("../..")
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from modular_splicing.mrs.experiment import (
    psam_examples_tra2a,
    mrs_statistics,
    main_analysis,
    nfm_analysis,
    ame_analysis,
)

# %%
mrs_statistics()
# Out:
# /mnt/md0/ExpeditionsCommon/spliceai/Canonical/modular_splicing/mrs/load.py:81: RuntimeWarning: invalid value encountered in divide
#   A5SS_fraction = (A5SS_fraction.T / A5SS_fraction.sum(1)).T
# the 3' dataset contains 1.69m datapoints whereas the 5' dataset contains only 265k datapoints
# the 3' dataset is much less balanced, with RII having a standard deviation of 0.36 whereas the 5' dataset has a standard deviation of 0.61

# %%
psam_examples_tra2a()

# %% [markdown]
# # Paper Figure and p values

# %%
main_analysis()

# %% [markdown]
# # Sanity check: does it work when using models trained on RBNS/eclip?

# %%
nfm_analysis()

# %%
ame_analysis()

# %% [markdown]
# # Smaller version of the figure

# %%
import matplotlib.pyplot as plt
scl = 1.3
_, axs = plt.subplots(1, 2, figsize=(5 * scl, 2.5 * scl), dpi=200, tight_layout=True)
main_analysis(axs)
