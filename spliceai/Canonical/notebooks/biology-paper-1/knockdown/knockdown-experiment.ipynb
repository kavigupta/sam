# %%
import os

os.chdir("../../..")
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import tqdm.auto as tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from modular_splicing.knockdown.experiment import plot_knockdown_experiment

# %%
_, axs = plt.subplots(1, 2, figsize=(7, 4), dpi=200, tight_layout=True)

plot_knockdown_experiment(axs[0], axs[1])

plt.show()
# Out:
# model: HepG2, K562:   0%|          | 0/11 [00:00<?, ?it/s]

# %%
scl = 1.3
_, axs = plt.subplots(1, 2, figsize=(3 * scl, 2.5 * scl), dpi=200, tight_layout=True)

plot_knockdown_experiment(axs[0], axs[1])

plt.show()
