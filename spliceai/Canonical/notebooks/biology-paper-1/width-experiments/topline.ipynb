# %%
import os

os.chdir("../../..")
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tqdm.notebook as tqdm

from modular_splicing.width_experiments.topline import series, color_map
from modular_splicing.utils.plots.results_by_model_group import plot_grouped_results
from modular_splicing.evaluation.evaluate_model_series import evaluate_all_series

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
results = evaluate_all_series(*series)

# %%
plt.figure(figsize=(5, 5), dpi=200, tight_layout=True)
plot_grouped_results(results, colors=color_map, ax=plt.gca())

# %%
absolute = (pd.DataFrame(results).mean() * 100)
absolute.round(1)
# Out:
# AM 21                                  79.0
# AM 17                                  78.0
# AM 13                                  77.3
# AM 13 + more layers                    76.9
# AM 13 + secondary struct.              77.7
# AM 13 + secondary struct. [control]    77.6
# AM 13 + flanks to 21                   77.0
# AM 13 + reprocessed (w=21 total)       77.6
# AM 13 + reprocessed (w=37 total)       78.4
# dtype: float64

# %%
(absolute - absolute["AM 13"]).round(2)
# Out:
# AM 21                                  1.72
# AM 17                                  0.66
# AM 13                                  0.00
# AM 13 + more layers                   -0.40
# AM 13 + secondary struct.              0.41
# AM 13 + secondary struct. [control]    0.30
# AM 13 + flanks to 21                  -0.28
# AM 13 + reprocessed (w=21 total)       0.31
# AM 13 + reprocessed (w=37 total)       1.09
# dtype: float64
